# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\TGX-100\Documents\GitHub\Urban-Traffic-Flow-Prediction\dataset\flows\GA058A_B.csv")

# %%
df.head()
# Out:
#          date  time  flow
# 0  2019-10-01     0     2
# 1  2019-10-01     1     1
# 2  2019-10-01     2     0
# 3  2019-10-01     3     0
# 4  2019-10-01     4     3
